# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data=pd.read_csv("Cleaned_Medicine_List_with_Alternatives.csv")

# %%
data
# Out:
#      Medicine Name        Composition                                Use Case  \
# 0         Dolo 650  Paracetamol 650mg  Fever, Headache, Mild to Moderate Pain
# 1           Calpol  Paracetamol 500mg     Fever, Body Ache, Cold-related Pain
# 2   Crocin Advance  Paracetamol 500mg              Fever, Headache, Mild Pain
# 3           Brufen    Ibuprofen 400mg           Fever, Toothache, Muscle Pain
# 4          Voveran  Diclofenac Sodium         Arthritis, Joint Pain, Swelling
# ..             ...                ...                                     ...
# 88         Domstal        Domperidone              Vomiting, Gastric Fullness
# 89           Ondem        Ondansetron               Vomiting, Motion Sickness
# 90          Emeset        Ondansetron                        Nausea, Vomiting
# 91            Looz          Lactulose           Constipation, Liver Cirrhosis
# 92        Duphalac          Lactulose            Constipation, Softens Stools
#
#                                      Type                     Drug Class
# 0                                  Tablet        Analgesic / Antipyretic
# 1                          Tablet / Syrup        Analgesic / Antipyretic
# 2                                  Tablet        Analgesic / Antipyretic
# 3                     Tablet / Suspension                          NSAID
# 4                Tablet / Gel / Injection                          NSAID
# ..                                    ...                            ...
# 88                    Tablet / Suspension        Antiemetic (Prokinetic)
# 89             Tablet / Syrup / Injection  Antiemetic (5-HT3 Antagonist)
# 90  Tablet / Oral Dispersible / Injection  Antiemetic (5-HT3 Antagonist)
# 91                                  Syrup           Laxative (Lactulose)
# 92                                  Syrup           Laxative (Lactulose)
#
# [93 rows x 5 columns]

# %%
data.isnull().sum()
# Out:
# Medicine Name    0
# Composition      0
# Use Case         0
# Type             0
# Drug Class       0
# dtype: int64

# %%
data.dtypes.astype(str)
# Out:
# Medicine Name    object
# Composition      object
# Use Case         object
# Type             object
# Drug Class       object
# dtype: object

# %%
plt.figure(figsize=(10,5))
sns.countplot(y="Drug Class", data=data, order=data["Drug Class"].value_counts().index, palette="viridis")
plt.title("Distribution of Drug Classes")
plt.xlabel("Count")
plt.ylabel("Drug Class")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[12], line 2
#       1 plt.figure(figsize=(10,5))
# ----> 2 sns.countplot(y="Drug Class", data=df, order=df["Drug Class"].value_counts().index, palette="viridis")
#       3 plt.title("Distribution of Drug Classes")
#       4 plt.xlabel("Count")
#
# NameError: name 'df' is not defined
